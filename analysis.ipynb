# %% [markdown]
# # Analyzing a comprehensive grid search.
# The following code loads and analyzes the datafile generated by `grid_search`. This is written in Python to take advantage of `numpy` and `pandas` packages –– and it does not require huge computations.

# %% [markdown]
# We import necessary packages:

# %%
import pickle

import numpy as np
import pandas as pd

# %% [markdown]
# The following only needs to be run once (uncomment to run). It pickles the entire `df` object as `df.p`, which allows easier access later.

# %%
# path = 'five_result.csv'
# df = pd.read_csv(path)
# df['Sum'] = df['1'] + df['2'] * 2 + df['3'] * 3 + df['4'] * 4 + df['5'] * 5
# df['Avg'] = df['Sum']/4006
# print(df)
# pickle.dump( df, open( "df.p", "wb" ) )

# %% [markdown]
# If you've already pickled the entire file as `df.p` (or downloaded the datafile), you can load it into memory here:

# %%
df = pickle.load(open("df.p", "rb"))

# %% [markdown]
# You may now use this as you would any pandas dataframe.

# %%
df.shape
